# %%
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
# Data for the bar plot
gender = ['Male', 'Female']
index = [577, 314]
colors = ['#39ff14', '#F8FF14']
# Create the bar plot
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(gender, index, color=colors)
plt.xlabel("Gender")
plt.ylabel("No of people onboarding ship")
plt.title("Number of People Onboarding Ship by Gender")
plt.show()

# %%
#Univariate Analysis:
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(data['Age'].dropna(), kde=True, color='darkblue')
plt.title('Age Distribution')
plt.subplot(1, 2, 2)
sns.countplot(data['Sex'], color='pink')
plt.title('Gender Distribution')
plt.show()

# %%
# Data for the pie chart
labels = ['C Cherbourg', 'Q Queenstown', 'S Southampton']
sizes = [0.553571, 0.389610, 0.336957]
colors = ['#F83E76', '#F07EFF', '#14DCFF']
explode = (0.1, 0, 0) 
# Create a pie chart
fig = plt.figure()
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
# Plotting the pie chart with customizations
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.2f%%', 
       shadow=True, startangle=140)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x="Age", y="Fare", hue="Survived", palette='bright', s=50, edgecolor='k', alpha=0.7)
plt.title("Scatter Plot of Age vs Fare", fontsize=16)
plt.xlabel("Age", fontsize=14)
plt.ylabel("Fare", fontsize=14)
plt.legend(title="Survived", title_fontsize='13', fontsize='12', loc='upper right')
plt.grid(True)
plt.show()
